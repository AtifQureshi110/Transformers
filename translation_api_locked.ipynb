# %% [markdown]
# <a href="https://colab.research.google.com/github/AtifQureshi110/Transformers/blob/main/translation_api_locked.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # installation of transformers.
# !pip install transformers -q

# %%
# is used for text tokenization and is required by certain language models and tokenizers in NLP tasks.
# !pip install sentencepiece -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.9 MB/s eta 0:00:00

# %%
# improting the pipeline.
from transformers import pipeline

# %%
import pickle

# %% [markdown]
# # arbic to english

# %%
from transformers import MarianMTModel, MarianTokenizer

# Load the pre-trained model and tokenizer for Arabic to English translation
model_name = "Helsinki-NLP/opus-mt-ar-en"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# Create a translation pipeline
translator_ab_en = pipeline("translation", model=model, tokenizer=tokenizer)

# model.save_pretrained("translation_model")
# tokenizer.save_pretrained("translation_model")
# Out:
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/917k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.13M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# pytorch_model.bin:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# ('translation_model/tokenizer_config.json',
#  'translation_model/special_tokens_map.json',
#  'translation_model/vocab.json',
#  'translation_model/source.spm',
#  'translation_model/target.spm',
#  'translation_model/added_tokens.json')

# %%
text_list = ["أنتم أيها السعوديون أكثر الناس إثارة للاشمئزاز في هذا العالم",
    "أنا حور.. أخت التي بدأتها ابنتك العام الماضي",
    "لقد كان سعيدًا بزوجته من قبل ولكن ابنتك دخلت حياته وبدأت في مواعدتها. لقد عرضت عليه وبدأت في مواعدته لمدة 6 أشهر من استخدام أخي الآن ابنتك تتركه.",
    "لقد دمرت زواجه عليه السلام ووضعته عليه قائلة كل هذا يحدث بسبب أخي",
    "إنها ليست امرأة صالحة اجعلها تجلس في المنزل.. لم يكن لديها مشكلة في استخدام أخي للتقبيل أو ممارسة العادة السرية أو ممارسة الجنس عندما يجتمعون ولكنها الآن تريد أن تصبح مسلمة فجأة",
    "إذا كان لديها أي خجل، فقل لها أن تموت من أجل تدمير زواج شخص ما أو اقتلها حتى لا يتم تدمير زواج أي شخص آخر على الإطلاق",
    "كان لدى أخي أيضًا العديد من الصور الجنسية وغير المشروعة لندى، لكنه حذفها لأنها أخبرته أنه سيتم القبض عليها"
]

# %%
ls=[]
for i in text_list:
  text_arb_eng = translator_ab_en(i)[0]['translation_text']
  ls.append(text_arb_eng)

# %%
ls
# Out:
# ['You Saudis are the most disgusting people in the world.',
#  "I'm Hor, the sister your daughter started last year.",
#  'He was happy with his wife before, but your daughter got into his life and started dating her.',
#  'I ruined his marriage on him, and I put him on him, saying it all happened because of my brother.',
#  "She's not a good woman, have her sit in the house... she didn't have a problem using my brother to kiss, masturbate or have sex when they meet, but now she wants to be a Muslim all of a sudden.",
#  "If she has any shame, tell her to die in order to destroy someone's marriage or kill her so that no one else's marriage is destroyed at all.",
#  'My brother also had a lot of sexual and illegal images of Nada, but he deleted them because she told him she was gonna be arrested.']

# %%
pickle.dump(model, open("model.pkl", "wb"))

# %%
pickle.dump(tokenizer, open("tokenizer.pkl", "wb"))

# %%
import requests

local_file_path = '/content/model.pkl'  # Replace this with the actual local file path

with open(local_file_path, 'rb') as file:
    content = file.read()

print(f"Content of the file:\n{content}")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import requests

file_url = 'https://example.com/content/model.pkl'  # Replace this with the actual URL of the file

response = requests.get(file_url)

with open('model.pkl', 'wb') as file:
    file.write(response.content)

print("File downloaded successfully.")

# %%
import shutil
shutil.make_archive("/content/translation_model", 'zip', "translation_model")
# Out:
# '/content/translation_model.zip'

# %%
from google.colab import files
files.download("/content/translation_model.zip")

# %%
model.save_pretrained("arabic_english_translation_model")
tokenizer.save_pretrained("arabic_english_translation_model")

# %%
ls =[" لقد كان سعيدًا بزوجته من قبل ولكن ابنتك دخلت حياته وبدأت في مواعدتها. لقد عرضت عليه وبدأت في مواعدته لمدة"]

# %%
text_arb_eng = translator_ab_en("أنتم أيها السعوديون أكثر الناس إثارة للاشمئزاز في هذا العالم")

# %%
أنا حور.. أخت التي بدأتها ابنتك العام الماضي

# %%
text_arb_eng = translator_ab_en("أنا حور.. أخت التي بدأتها ابنتك العام الماضي")

# %%
text_arb_eng
# Out:
# [{'translation_text': "I'm Hor, the sister your daughter started last year."}]

# %% [markdown]
# # French to English

# %%
# make a instance of translation pipeline
translate_fr_en = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
then i used translation pipeline with a model Helsinki-NLP/opus-mt-fr-en named  in this pipeline this basically translatethe text into a langiuage whihch you want such from franch to english
# make a instance of translation pipeline
translate_fr_en = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
# translation of franch text into english by a instance of translation pipeline .
translated_text_fr_en = translate_fr_en("Bonjour, comment ça va atif?")

# %%
# output in english.
translated_text_fr_en
# Out:
# [{'translation_text': "Hello, how's it going?"}]

# %%
# creating custom dataset which have all the information in french and our task is to convert them into any understandable language here i perfer it to english.
import pandas as pd
data = [  "La bronchite est l'inflammation de la muqueuse des grandes voies respiratoires appelées bronches dans les poumons.",
    "L'intelligence artificielle (IA) fait référence à la simulation de processus cognitifs humains par des machines.",
    "Le changement climatique résulte de l'accumulation de gaz à effet de serre dans l'atmosphère, provoquant des variations climatiques.",
    "La mondialisation désigne l'interconnexion croissante des économies, cultures et sociétés à l'échelle mondiale.",
    "Le diabète de type 2 est une maladie chronique caractérisée par une résistance à l'insuline et des niveaux élevés de glucose dans le sang.",
    "L'énergie solaire est produite par la conversion de la lumière du soleil en électricité à l'aide de panneaux solaires.",
    "La Révolution industrielle a marqué une période de transformation majeure de la production, passant de méthodes artisanales à la manufacture.",
    "Le développement durable vise à répondre aux besoins du présent sans compromettre les ressources pour les générations futures.",
    "La guerre froide était une période de tension géopolitique entre les États-Unis et l'Union soviétique après la Seconde Guerre mondiale.",
    "Le cancer est une maladie caractérisée par la croissance incontrôlée de cellules anormales dans le corps.",
    "Les énergies renouvelables, telles que l'éolien et l'hydroélectricité, sont des sources d'énergie écologiques et durables.",
    "La littérature classique française comprend des œuvres emblématiques de Molière, Voltaire, et Victor Hugo.",
    "La démocratie est un système politique dans lequel le pouvoir est exercé par le peuple, souvent par le biais d'élections.",
    "La crise économique de 2008 a entraîné des répercussions mondiales, affectant les marchés financiers et l'emploi.",
    "La culture populaire englobe les éléments culturels préférés par la majorité, comme la musique, les films et la mode."]

df = pd.DataFrame(data, columns=["French Description"])
# Display the DataFrame
df
# Out:
#                                    French Description
# 0   La bronchite est l'inflammation de la muqueuse...
# 1   L'intelligence artificielle (IA) fait référenc...
# 2   Le changement climatique résulte de l'accumula...
# 3   La mondialisation désigne l'interconnexion cro...
# 4   Le diabète de type 2 est une maladie chronique...
# 5   L'énergie solaire est produite par la conversi...
# 6   La Révolution industrielle a marqué une périod...
# 7   Le développement durable vise à répondre aux b...
# 8   La guerre froide était une période de tension ...
# 9   Le cancer est une maladie caractérisée par la ...
# 10  Les énergies renouvelables, telles que l'éolie...
# 11  La littérature classique française comprend de...
# 12  La démocratie est un système politique dans le...
# 13  La crise économique de 2008 a entraîné des rép...
# 14  La culture populaire englobe les éléments cult...

# %%
# loop is used to convert all frnech text in df into english with help of "translate_fr_en" which is instance of pipeline.
translator_list = []
for i in df['French Description']:
  translated_text_fr_en = translate_fr_en(i)
  translator_list.append(translated_text_fr_en)

# %%
# output of the list is but i has some extara information and i need onlyt the text.
translator_list
# Out:
# [[{'translation_text': 'Bronchitis is the inflammation of the mucous membrane of the large airways called bronchi in the lungs.'}],
#  [{'translation_text': 'Artificial intelligence (AI) refers to the simulation of human cognitive processes by machines.'}],
#  [{'translation_text': 'Climate change is the result of the accumulation of greenhouse gases in the atmosphere, causing climate change.'}],
#  [{'translation_text': 'Globalization refers to the growing interconnection of global economies, cultures and societies.'}],
#  [{'translation_text': 'Type 2 diabetes is a chronic disease characterized by insulin resistance and high levels of glucose in the blood.'}],
#  [{'translation_text': 'Solar energy is produced by converting sunlight into electricity using solar panels.'}],
#  [{'translation_text': 'The Industrial Revolution marked a period of major transformation of production, from artisanal methods to manufacturing.'}],
# ...

# %%
# here i used two loop to extract the specific infor mation on my requirdement.
fliter_list= []
for i in translator_list:
  for x in i:
    fliter_list.append(x["translation_text"])

# %%
# now this filter list has transalted text in engish from french language.
fliter_list
# Out:
# ['Bronchitis is the inflammation of the mucous membrane of the large airways called bronchi in the lungs.',
#  'Artificial intelligence (AI) refers to the simulation of human cognitive processes by machines.',
#  'Climate change is the result of the accumulation of greenhouse gases in the atmosphere, causing climate change.',
#  'Globalization refers to the growing interconnection of global economies, cultures and societies.',
#  'Type 2 diabetes is a chronic disease characterized by insulin resistance and high levels of glucose in the blood.',
#  'Solar energy is produced by converting sunlight into electricity using solar panels.',
#  'The Industrial Revolution marked a period of major transformation of production, from artisanal methods to manufacturing.',
#  'Sustainable development aims to meet the needs of the present without compromising resources for future generations.',
# ...

# %%
# finally adding thelist into the atual data frame.
df["Translated English Description"] = fliter_list

# %%
# FINAL DATA FRAME.
df
# Out:
#                                    French Description  \
# 0   La bronchite est l'inflammation de la muqueuse...
# 1   L'intelligence artificielle (IA) fait référenc...
# 2   Le changement climatique résulte de l'accumula...
# 3   La mondialisation désigne l'interconnexion cro...
# 4   Le diabète de type 2 est une maladie chronique...
# 5   L'énergie solaire est produite par la conversi...
# 6   La Révolution industrielle a marqué une périod...
# 7   Le développement durable vise à répondre aux b...
# 8   La guerre froide était une période de tension ...
# 9   Le cancer est une maladie caractérisée par la ...
# 10  Les énergies renouvelables, telles que l'éolie...
# 11  La littérature classique française comprend de...
# 12  La démocratie est un système politique dans le...
# 13  La crise économique de 2008 a entraîné des rép...
# 14  La culture populaire englobe les éléments cult...
#
#                        Translated English Description
# ...

# %% [markdown]
# # urdu to English

# %%
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-ur-en")
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
urdu_text = "عوامی موسیقی، فلمیں اور موڈ جیسے مختار اصولوں کو شامل کرتی ہوئی عوامی ثقافت۔"
english_translation = translator(urdu_text)[0]['translation_text']
print("Urdu Text:", urdu_text)
print("English Translation:", english_translation)
# Out:
# Urdu Text: عوامی موسیقی، فلمیں اور موڈ جیسے مختار اصولوں کو شامل کرتی ہوئی عوامی ثقافت۔
# English Translation: Public music, movies, and modes include public culture that are common.

# %%
import pandas as pd

data_urdu = [
    "برانکائٹ پھیپھڑوں کی لائننگ میں سوزش ہوتی ہے جو پھیپھڑوں کو انفیضیہ کی بڑی لائننگ کے نام سے پکارا جاتا ہے جو پھیپھڑوں میں ہوتی ہے۔",
    "خودکار ذہانت (AI) آلات کی طرف سے انسانی تشکیلی عملوں کی نقلی کیمیائیاً پروسیس کو موازنہ کرتا ہے۔",
    "جلوائی اثرات کے گیسوں کے انباش کی انبلا ہوا میں جمع ہونے سے جوابی تبدیلیوں کو وجود میں لاتا ہے، جو جوابی تبدیلیوں کو پیدا کرتا ہے۔",
    "عالمی شجرت واسطے اقتصادوں، ثقافتوں اور معاشرتوں کے بڑھتے ہوئے تعلقات کی مشابہت کو ظاہر کرتی ہے۔",
    "ٹائپ 2 شوگر کی بیماری ایک دائمی بیماری ہے جو خود کو انسولن کی مزیدیت اور خون میں قند کی بلندی کی خصوصیات سے کرکٹ کرتی ہے۔",
    "سورج کی روشنی کو بجلی میں تبدیل کرکے شمسی توانائی پیدا ہوتی ہے جس میں پینلز کی مدد سے کیا جاتا ہے۔",
    "صنعتی انقلاب نے پیداوار کی اہم تبدیلی کی مدت کو نمونی اور دستی تراکیب سے منسلک کرنے کی ایک مدت معین کی۔",
    "پذیرائی کی ترقی موجودہ کی ضروریات کو پورا کرنے کیلئے اور آنے والی نسلوں کے لئے وسائل کو خراب نہ کرنے کی خاطر کی جاتی ہے۔",
    "سرد جنگ دونوں جنگ امریکہ اور روس کے درمیان بعد دومی جنگ عظیم میں بڑھتی جئے کو جوابی تناظر کا نام ہے۔",
    "کینسر ایک بیماری ہے جس کی خصوصیت ہے کہ جسم کے انوکھی خلیوں کی غیر قابو کی جانے والی نشوونما ہوتی ہے۔",
    "نئی توانائیاں جیسے بادشاہتی اور بجلی اندرونی توانائی اور مستدام توانائی کے ذرائع ہیں۔",
    "فرانسیسی کلاسیکی ادب میں مولیئر، وولٹیئر اور وکٹر ہگو کی معروفی حاصل کرنے والی کتب شامل ہیں۔",
    "جمہوریت ایک سیاسی نظام ہے جس میں قوت عوام کے ذریعے عموماً انتخابات کے ذریعے استعمال ہوتی ہے۔",
    "2008 کی معاشی کریز نے عالمی تبدیلیوں کو پیدا کیا، جس نے مالیتی مارکیٹس اور ملازمت کو متاثر کیا۔",
    "عوامی موسیقی، فلمیں اور موڈ جیسے مختار اصولوں کو شامل کرتی ہوئی عوامی ثقافت۔",]

df_urdu = pd.DataFrame(data_urdu, columns=["تفصیل"])
# Display the DataFrame in Urdu
df_urdu
# Out:
#                                                 تفصیل
# 0   برانکائٹ پھیپھڑوں کی لائننگ میں سوزش ہوتی ہے ج...
# 1   خودکار ذہانت (AI) آلات کی طرف سے انسانی تشکیلی...
# 2   جلوائی اثرات کے گیسوں کے انباش کی انبلا ہوا می...
# 3   عالمی شجرت واسطے اقتصادوں، ثقافتوں اور معاشرتو...
# 4   ٹائپ 2 شوگر کی بیماری ایک دائمی بیماری ہے جو خ...
# 5   سورج کی روشنی کو بجلی میں تبدیل کرکے شمسی توان...
# 6   صنعتی انقلاب نے پیداوار کی اہم تبدیلی کی مدت ک...
# 7   پذیرائی کی ترقی موجودہ کی ضروریات کو پورا کرنے...
# 8   سرد جنگ دونوں جنگ امریکہ اور روس کے درمیان بعد...
# 9   کینسر ایک بیماری ہے جس کی خصوصیت ہے کہ جسم کے ...
# 10  نئی توانائیاں جیسے بادشاہتی اور بجلی اندرونی ت...
# 11  فرانسیسی کلاسیکی ادب میں مولیئر، وولٹیئر اور و...
# 12  جمہوریت ایک سیاسی نظام ہے جس میں قوت عوام کے ذ...
# 13  2008 کی معاشی کریز نے عالمی تبدیلیوں کو پیدا ک...
# 14  عوامی موسیقی، فلمیں اور موڈ جیسے مختار اصولوں ...

# %%
# loop is used to convert all frnech text in df into english with help of "translate_fr_en" which is instance of pipeline.
translator_list = []
for i in df_urdu['تفصیل']:
  translated_text_ur_en = translator(i)[0]['translation_text']
  translator_list.append(translated_text_ur_en)

# %%
translator_list
# Out:
# ['Bone’s heart is added to the stroke of Hong Kong, which is called one of the biggest strokes called Hong Kong’s syndrome that is in Hong Kong.',
#  'Automatics compare human design with the making of human actions (the tools of tools) that are created by tools.',
#  'The gathered in the air of the non-sensitation effect of the non-sensitation effect does create change, which begins to change the results.',
#  'The same is true of the many relationships that spread throughout the world for culture, cultures, and so forth.',
#  'The type of 2 diabetes is a chronic illness that enables itself to develop the high - quality properties of the Tyrado and the high quality of the blood in the blood.',
#  'The sun’s light is transformed into electricity and produces solar energy, which is used to help make the sun shine.',
#  'The industrial revolution has set a time for connecting the time of the important change of growth to renovate and bification.',
# ...

# %%
df_urdu["ترجمہ انگریزی"] = translator_list

# %%
df_urdu
# Out:
#                                                 تفصیل  \
# 0   برانکائٹ پھیپھڑوں کی لائننگ میں سوزش ہوتی ہے ج...
# 1   خودکار ذہانت (AI) آلات کی طرف سے انسانی تشکیلی...
# 2   جلوائی اثرات کے گیسوں کے انباش کی انبلا ہوا می...
# 3   عالمی شجرت واسطے اقتصادوں، ثقافتوں اور معاشرتو...
# 4   ٹائپ 2 شوگر کی بیماری ایک دائمی بیماری ہے جو خ...
# 5   سورج کی روشنی کو بجلی میں تبدیل کرکے شمسی توان...
# 6   صنعتی انقلاب نے پیداوار کی اہم تبدیلی کی مدت ک...
# 7   پذیرائی کی ترقی موجودہ کی ضروریات کو پورا کرنے...
# 8   سرد جنگ دونوں جنگ امریکہ اور روس کے درمیان بعد...
# 9   کینسر ایک بیماری ہے جس کی خصوصیت ہے کہ جسم کے ...
# 10  نئی توانائیاں جیسے بادشاہتی اور بجلی اندرونی ت...
# 11  فرانسیسی کلاسیکی ادب میں مولیئر، وولٹیئر اور و...
# 12  جمہوریت ایک سیاسی نظام ہے جس میں قوت عوام کے ذ...
# 13  2008 کی معاشی کریز نے عالمی تبدیلیوں کو پیدا ک...
# 14  عوامی موسیقی، فلمیں اور موڈ جیسے مختار اصولوں ...
#
#                                         ترجمہ انگریزی
# ...

# %%
# Choose the MarianMT model for Chinese to English translation
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-zh-en")

# Example translation
text_to_translate = "你好，世界！"
translated_text = translator(text_to_translate, max_length=40)[0]['translation_text']

print(f"Original text: {text_to_translate}")
print(f"Translated text: {translated_text}")
# Out:
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/805k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/807k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.62M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Original text: 你好，世界！
# Translated text: Hello, world!
