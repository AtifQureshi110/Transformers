# %% [markdown]
# <a href="https://colab.research.google.com/github/AtifQureshi110/Transformers/blob/main/pipeline_sentiment_analysis_locked.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers -q

# %%
from transformers import pipeline, BertTokenizer, BertForSequenceClassification

# %%
# Load a BERT-based sentiment analysis model
model_name = "nlptown/bert-base-multilingual-uncased-sentiment"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForSequenceClassification.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/669M [00:00<?, ?B/s]

# %%
# Create the pipeline
sentiment_classifier = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# %%
# Example usage
result = sentiment_classifier("I love using transformers!")
print(result)
# Out:
# [{'label': '5 stars', 'score': 0.8677474856376648}]

# %%
sentiment_classifier("Today was an incredible day! I aced my presentation and received praise from my colleagues. Feeling on top of the world right now! 😄🎉")
# Out:
# [{'label': '5 stars', 'score': 0.9234662055969238}]

# %%
import pickle

# %%
pickle.dump(classifier, open("classifier.pkl", "wb"))

# %%
import pandas as pd
data = {
    'Sentiment': ["Today was an incredible day! I aced my presentation and received praise from my colleagues. Feeling on top of the world right now! 😄🎉",
        "Absolutely loved the new restaurant in town. The food was exceptional, and the ambiance was perfect for a cozy dinner. Highly recommended!",
        "Just adopted the most adorable puppy. My heart is melting every time it cuddles up to me. Can't wait for all the new adventures together! 🐶❤️",
        "Finished reading a fantastic book that left me completely engrossed. The author's storytelling skills are beyond impressive. Can't wait to explore more of their work!",
        "Spent the day at the beach with friends, basking in the sun and enjoying the waves. Nothing beats the feeling of sand between your toes and laughter in the air. ☀️🏖️",
        "Today was just one of those days. Everything seemed to go wrong, from missing my bus to spilling coffee all over my work. Can't wait for this day to end.",
        "Disappointed by the service at the new cafe. The staff was rude, and the food took forever to arrive. Won't be going back there anytime soon.",
        "Lost my wallet today, along with all my important cards and cash. Feeling frustrated and stressed about the hassle of replacing everything.",
        "Tried watching a highly recommended movie, but it turned out to be a complete bore. Two hours of my life I'll never get back.",
        "Had to deal with a flat tire on my way to an important meeting. Just when you think things can't get worse, they do."],
    'Sentiment Type': [
        'Positive', 'Positive', 'Positive', 'Positive', 'Positive',
        'Negative', 'Negative', 'Negative', 'Negative', 'Negative'
    ]
}
df = pd.DataFrame(data)
df
# Out:
#                                            Sentiment Sentiment Type
# 0  Today was an incredible day! I aced my present...       Positive
# 1  Absolutely loved the new restaurant in town. T...       Positive
# 2  Just adopted the most adorable puppy. My heart...       Positive
# 3  Finished reading a fantastic book that left me...       Positive
# 4  Spent the day at the beach with friends, baski...       Positive
# 5  Today was just one of those days. Everything s...       Negative
# 6  Disappointed by the service at the new cafe. T...       Negative
# 7  Lost my wallet today, along with all my import...       Negative
# 8  Tried watching a highly recommended movie, but...       Negative
# 9  Had to deal with a flat tire on my way to an i...       Negative

# %%
label_list = []
for i in df.Sentiment:
  results = classifier(i)[0]['label']
  label_list.append(results)
  print(results)
# Out:
# POSITIVE
# POSITIVE
# POSITIVE
# POSITIVE
# POSITIVE
# NEGATIVE
# NEGATIVE
# NEGATIVE
# NEGATIVE
# NEGATIVE

# %%
df['predicated_labels'] = label_list

# %%
df
# Out:
#                                            Sentiment Sentiment Type  \
# 0  Today was an incredible day! I aced my present...       Positive
# 1  Absolutely loved the new restaurant in town. T...       Positive
# 2  Just adopted the most adorable puppy. My heart...       Positive
# 3  Finished reading a fantastic book that left me...       Positive
# 4  Spent the day at the beach with friends, baski...       Positive
# 5  Today was just one of those days. Everything s...       Negative
# 6  Disappointed by the service at the new cafe. T...       Negative
# 7  Lost my wallet today, along with all my import...       Negative
# 8  Tried watching a highly recommended movie, but...       Negative
# 9  Had to deal with a flat tire on my way to an i...       Negative
#
#   predicated_labels
# 0          POSITIVE
# 1          POSITIVE
# 2          POSITIVE
# 3          POSITIVE
# 4          POSITIVE
# 5          NEGATIVE
# 6          NEGATIVE
# 7          NEGATIVE
# 8          NEGATIVE
# ...
